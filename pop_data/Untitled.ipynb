# %%
import pandas as pd
import numpy as np
import json
from us import states

# %%
population = pd.read_csv(open('congressional_district_population.csv'))

# %%
population
# Out:
#     District       Urban     Suburban       Rural  Urban %  Suburban %  \
# 0     U.S.A.  83,171,109  169,710,405  68,122,772     25.9        52.9
# 1    Alabama     967,111    2,004,018   1,879,647     19.9        41.3
# 2      AL-01     148,964      302,147     255,481     21.1        42.8
# 3      AL-02     146,722      253,542     281,148     21.5        37.2
# 4      AL-03     118,205      273,994     316,656     16.7        38.7
# ..       ...         ...          ...         ...      ...         ...
# 483    WI-06     111,041      371,196     230,104     15.6        52.1
# 484    WI-07      93,645      176,870     433,122     13.3        25.1
# 485    WI-08     141,782      312,855     272,676     19.5        43.0
# 486  Wyoming     105,583      257,596     220,020     18.1        44.2
# 487    WY-AL     105,583      257,596     220,020     18.1        44.2
#
#      Rural % Most Prevalent
# 0       21.2       Suburban
# 1       38.7       Suburban
# ...

# %%
state_list = []
states2abbr = dict()
for state in states.STATES:
    state_list.append(state.name)
    states2abbr[state.name] = state.abbr

# %%
state_pops = population[population['District'].isin(state_list)].reset_index(drop=True)

# %%
def clean_states(in_df):
    df = in_df.copy()
    df = df.rename(columns={'District': 'state_po', 'Urban': 'urban', 'Suburban': 'suburban', 'Rural': 'rural', 
                            'Urban %': 'urban_pct', 'Suburban %': 'suburban_pct',
                            'Rural %': 'rural_pct', 'Most Prevalent': 'prevalent'})
    df['urban_pct'] /= 100
    df['suburban_pct'] /= 100
    df['rural_pct'] /= 100
    df['state_po'] = list(map(lambda x: states2abbr[x], state_pops['District']))
    df['prevalent'] = (df['prevalent']).str.lower()
    return df

# %%
clean_states(state_pops)
# Out:
#    state_po       urban    suburban      rural  urban_pct  suburban_pct  \
# 0        AL     967,111   2,004,018  1,879,647      0.199         0.413
# 1        AK     162,281     367,243    209,041      0.220         0.497
# 2        AZ   1,859,473   4,038,989    911,472      0.273         0.593
# 3        AR     596,803   1,116,106  1,265,033      0.200         0.375
# 4        CA  12,792,442  23,249,186  2,941,224      0.328         0.596
# 5        CO   1,251,318   3,371,242    813,959      0.230         0.620
# 6        CT     780,783   2,287,459    526,232      0.217         0.636
# 7        DE     158,557     576,003    209,169      0.168         0.610
# 8        FL   4,820,072  12,937,010  2,521,349      0.238         0.638
# 9        GA   1,745,555   5,703,741  2,752,349      0.171         0.559
# 10       HI     383,538     804,884    233,234      0.270         0.566
# 11       ID     256,176     818,391    582,804      0.155         0.494
# ...

# %%
# Out:
# ['AL',
#  'AK',
#  'AZ',
#  'AR',
#  'CA',
#  'CO',
#  'CT',
#  'DE',
#  'FL',
#  'GA',
#  'HI',
#  'ID',
#  'IL',
#  'IN',
#  'IA',
#  'KS',
#  'KY',
#  'LA',
#  'ME',
#  'MD',
#  'MA',
#  'MI',
#  'MN',
#  'MS',
#  'MO',
#  'MT',
#  'NE',
#  'NV',
#  'NH',
#  'NJ',
#  'NM',
#  'NY',
#  'NC',
#  'ND',
#  'OH',
#  'OK',
#  'OR',
#  'PA',
#  'RI',
#  'SC',
#  'SD',
#  'TN',
#  'TX',
#  'UT',
#  'VT',
#  'VA',
#  'WA',
#  'WV',
#  'WI',
#  'WY']
