# %%
from census import Census
from us import states
from pprint import pprint as print
from IPython.display import clear_output

# %%
import json
keys = json.load(open('api_keys.json'))

# %%
c = Census(keys['census'])

# %%
# for code, table in list(c.acs5.fields().items()):
#     try:
#         if table['concept'].lower().find('race') != -1:
#             print(table['concept'])
#     except:
#         pass

# %%
c.acs1.get(("NAME", "B16005F"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-610e51e44049> in <module>
# ----> 1 c.acs1.get(("NAME", "B16005F"))
#
# /usr/local/Caskroom/miniconda/base/envs/polling/lib/python3.8/site-packages/census/core.py in get(self, *args, **kwargs)
#     296         self._switch_endpoints(kwargs.get('year', self.default_year))
#     297
# --> 298         return super(ACSClient, self).get(*args, **kwargs)
#     299
#     300 class ACS5Client(ACSClient):
#
# TypeError: get() missing 1 required positional argument: 'geo'

# %%
# Out:
# {'for': {'label': "Census API FIPS 'for' clause",
#   'concept': 'Census API Geography Specification',
#   'predicateType': 'fips-for',
#   'group': 'N/A',
#   'limit': 0,
#   'predicateOnly': True},
#  'in': {'label': "Census API FIPS 'in' clause",
#   'concept': 'Census API Geography Specification',
#   'predicateType': 'fips-in',
#   'group': 'N/A',
#   'limit': 0,
#   'predicateOnly': True},
#  'B99104_007E': {'label': 'Estimate!!Total!!Not living with own grandchildren under 18 years',
#   'concept': 'ALLOCATION OF LENGTH OF TIME GRANDPARENT RESPONSIBLE FOR OWN GRANDCHILDREN UNDER 18 YEARS FOR THE POPULATION 30 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B99104',
#   'limit': 0,
#   'attributes': 'B99104_007EA'},
#  'B24022_060E': {'label': 'Estimate!!Total!!Female!!Service occupations!!Food preparation and serving related occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_060M,B24022_060MA,B24022_060EA'},
#  'B11011_007E': {'label': 'Estimate!!Total!!Family households!!Other family',
#   'concept': 'HOUSEHOLD TYPE BY UNITS IN STRUCTURE',
#   'predicateType': 'int',
#   'group': 'B11011',
#   'limit': 0,
#   'attributes': 'B11011_007M,B11011_007MA,B11011_007EA'},
#  'B19001B_014E': {'label': 'Estimate!!Total!!$100,000 to $124,999',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_014M,B19001B_014MA,B19001B_014EA'},
#  'B24032_049E': {'label': 'Estimate!!Female!!Educational services, and health care and social assistance!!Health care and social assistance',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24032',
#   'limit': 0,
#   'attributes': 'B24032_049M,B24032_049MA,B24032_049EA'},
#  'B11011_006E': {'label': 'Estimate!!Total!!Family households!!Married-couple family!!Mobile homes and all other types of units',
#   'concept': 'HOUSEHOLD TYPE BY UNITS IN STRUCTURE',
#   'predicateType': 'int',
#   'group': 'B11011',
#   'limit': 0,
#   'attributes': 'B11011_006M,B11011_006MA,B11011_006EA'},
#  'B07007PR_019E': {'label': 'Estimate!!Total!!Moved from different municipio!!Foreign born!!Naturalized U.S. citizen',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_019M,B07007PR_019MA,B07007PR_019EA'},
#  'B19101A_004E': {'label': 'Estimate!!Total!!$15,000 to $19,999',
#   'concept': 'FAMILY INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19101A',
#   'limit': 0,
#   'attributes': 'B19101A_004M,B19101A_004MA,B19101A_004EA'},
#  'B08113_045E': {'label': 'Estimate!!Total!!Taxicab, motorcycle, bicycle, or other means!!Speak Spanish!!Speak English less than "very well"',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH',
#   'predicateType': 'int',
#   'group': 'B08113',
#   'limit': 0,
#   'attributes': 'B08113_045M,B08113_045MA,B08113_045EA'},
#  'B24022_061E': {'label': 'Estimate!!Total!!Female!!Service occupations!!Building and grounds cleaning and maintenance occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_061M,B24022_061MA,B24022_061EA'},
#  'B11011_008E': {'label': 'Estimate!!Total!!Family households!!Other family!!Male householder, no wife present',
#   'concept': 'HOUSEHOLD TYPE BY UNITS IN STRUCTURE',
#   'predicateType': 'int',
#   'group': 'B11011',
#   'limit': 0,
#   'attributes': 'B11011_008M,B11011_008MA,B11011_008EA'},
#  'B19001B_013E': {'label': 'Estimate!!Total!!$75,000 to $99,999',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_013M,B19001B_013MA,B19001B_013EA'},
#  'B24032_048E': {'label': 'Estimate!!Female!!Educational services, and health care and social assistance!!Educational services',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24032',
#   'limit': 0,
#   'attributes': 'B24032_048M,B24032_048MA,B24032_048EA'},
#  'B07007PR_018E': {'label': 'Estimate!!Total!!Moved from different municipio!!Foreign born',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_018M,B07007PR_018MA,B07007PR_018EA'},
#  'B19101A_005E': {'label': 'Estimate!!Total!!$20,000 to $24,999',
#   'concept': 'FAMILY INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19101A',
#   'limit': 0,
#   'attributes': 'B19101A_005M,B19101A_005MA,B19101A_005EA'},
#  'B08113_044E': {'label': 'Estimate!!Total!!Taxicab, motorcycle, bicycle, or other means!!Speak Spanish!!Speak English "very well"',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH',
#   'predicateType': 'int',
#   'group': 'B08113',
#   'limit': 0,
#   'attributes': 'B08113_044M,B08113_044MA,B08113_044EA'},
#  'B99104_005E': {'label': 'Estimate!!Total!!Living with own grandchildren under 18 years!!Grandparent responsible for own grandchildren under 18 years!!Length of time!!Not allocated',
#   'concept': 'ALLOCATION OF LENGTH OF TIME GRANDPARENT RESPONSIBLE FOR OWN GRANDCHILDREN UNDER 18 YEARS FOR THE POPULATION 30 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B99104',
#   'limit': 0,
#   'attributes': 'B99104_005EA'},
#  'B19001B_012E': {'label': 'Estimate!!Total!!$60,000 to $74,999',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_012M,B19001B_012MA,B19001B_012EA'},
#  'B24022_062E': {'label': 'Estimate!!Total!!Female!!Service occupations!!Personal care and service occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_062M,B24022_062MA,B24022_062EA'},
#  'B24032_047E': {'label': 'Estimate!!Female!!Educational services, and health care and social assistance',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24032',
#   'limit': 0,
#   'attributes': 'B24032_047M,B24032_047MA,B24032_047EA'},
#  'B11011_004E': {'label': 'Estimate!!Total!!Family households!!Married-couple family!!1-unit structures',
#   'concept': 'HOUSEHOLD TYPE BY UNITS IN STRUCTURE',
#   'predicateType': 'int',
#   'group': 'B11011',
#   'limit': 0,
#   'attributes': 'B11011_004M,B11011_004MA,B11011_004EA'},
#  'B01001B_029E': {'label': 'Estimate!!Total!!Female!!65 to 74 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_029M,B01001B_029MA,B01001B_029EA'},
#  'B19101A_006E': {'label': 'Estimate!!Total!!$25,000 to $29,999',
#   'concept': 'FAMILY INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19101A',
#   'limit': 0,
#   'attributes': 'B19101A_006M,B19101A_006MA,B19101A_006EA'},
#  'B20005A_021E': {'label': 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With earnings!!$50,000 to $54,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_021M,B20005A_021MA,B20005A_021EA'},
#  'B07007PR_017E': {'label': 'Estimate!!Total!!Moved from different municipio!!Native',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_017M,B07007PR_017MA,B07007PR_017EA'},
#  'B08113_047E': {'label': 'Estimate!!Total!!Taxicab, motorcycle, bicycle, or other means!!Speak other languages!!Speak English "very well"',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH',
#   'predicateType': 'int',
#   'group': 'B08113',
#   'limit': 0,
#   'attributes': 'B08113_047M,B08113_047MA,B08113_047EA'},
#  'B06010_041E': {'label': 'Estimate!!Total!!Native; born outside the United States!!With income!!$35,000 to $49,999',
#   'concept': 'PLACE OF BIRTH BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06010',
#   'limit': 0,
#   'attributes': 'B06010_041M,B06010_041MA,B06010_041EA'},
#  'B24022_063E': {'label': 'Estimate!!Total!!Female!!Sales and office occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_063M,B24022_063MA,B24022_063EA'},
#  'B07007PR_015E': {'label': 'Estimate!!Total!!Moved within same municipio!!Foreign born!!Not a U.S. citizen',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_015M,B07007PR_015MA,B07007PR_015EA'},
#  'B19001B_011E': {'label': 'Estimate!!Total!!$50,000 to $59,999',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_011M,B19001B_011MA,B19001B_011EA'},
#  'B99104_006E': {'label': 'Estimate!!Total!!Living with own grandchildren under 18 years!!Grandparent not responsible for own grandchildren under 18 years',
#   'concept': 'ALLOCATION OF LENGTH OF TIME GRANDPARENT RESPONSIBLE FOR OWN GRANDCHILDREN UNDER 18 YEARS FOR THE POPULATION 30 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B99104',
#   'limit': 0,
#   'attributes': 'B99104_006EA'},
#  'B19013G_001E': {'label': 'Estimate!!Median household income in the past 12 months (in 2016 inflation-adjusted dollars)',
#   'concept': 'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (TWO OR MORE RACES HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19013G',
#   'limit': 0,
#   'attributes': 'B19013G_001M,B19013G_001MA,B19013G_001EA'},
#  'B24032_046E': {'label': 'Estimate!!Female!!Professional, scientific, and management, and administrative and waste management services!!Administrative and support and waste management services',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24032',
#   'limit': 0,
#   'attributes': 'B24032_046M,B24032_046MA,B24032_046EA'},
#  'B11011_005E': {'label': 'Estimate!!Total!!Family households!!Married-couple family!!2-or-more-unit structures',
#   'concept': 'HOUSEHOLD TYPE BY UNITS IN STRUCTURE',
#   'predicateType': 'int',
#   'group': 'B11011',
#   'limit': 0,
#   'attributes': 'B11011_005M,B11011_005MA,B11011_005EA'},
#  'B19101A_007E': {'label': 'Estimate!!Total!!$30,000 to $34,999',
#   'concept': 'FAMILY INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19101A',
#   'limit': 0,
#   'attributes': 'B19101A_007M,B19101A_007MA,B19101A_007EA'},
#  'B20005A_020E': {'label': 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With earnings!!$45,000 to $49,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_020M,B20005A_020MA,B20005A_020EA'},
#  'B07007PR_016E': {'label': 'Estimate!!Total!!Moved from different municipio',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_016M,B07007PR_016MA,B07007PR_016EA'},
#  'B08113_046E': {'label': 'Estimate!!Total!!Taxicab, motorcycle, bicycle, or other means!!Speak other languages',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH',
#   'predicateType': 'int',
#   'group': 'B08113',
#   'limit': 0,
#   'attributes': 'B08113_046M,B08113_046MA,B08113_046EA'},
#  'B06010_040E': {'label': 'Estimate!!Total!!Native; born outside the United States!!With income!!$25,000 to $34,999',
#   'concept': 'PLACE OF BIRTH BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06010',
#   'limit': 0,
#   'attributes': 'B06010_040M,B06010_040MA,B06010_040EA'},
#  'B99104_003E': {'label': 'Estimate!!Total!!Living with own grandchildren under 18 years!!Grandparent responsible for own grandchildren under 18 years',
#   'concept': 'ALLOCATION OF LENGTH OF TIME GRANDPARENT RESPONSIBLE FOR OWN GRANDCHILDREN UNDER 18 YEARS FOR THE POPULATION 30 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B99104',
#   'limit': 0,
#   'attributes': 'B99104_003EA'},
#  'B24022_064E': {'label': 'Estimate!!Total!!Female!!Sales and office occupations!!Sales and related occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_064M,B24022_064MA,B24022_064EA'},
#  'B19001B_010E': {'label': 'Estimate!!Total!!$45,000 to $49,999',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_010M,B19001B_010MA,B19001B_010EA'},
#  'B25051_001E': {'label': 'Estimate!!Total',
#   'concept': 'KITCHEN FACILITIES FOR ALL HOUSING UNITS',
#   'predicateType': 'int',
#   'group': 'B25051',
#   'limit': 0,
#   'attributes': 'B25051_001M,B25051_001MA,B25051_001EA'},
#  'B24032_045E': {'label': 'Estimate!!Female!!Professional, scientific, and management, and administrative and waste management services!!Management of companies and enterprises',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24032',
#   'limit': 0,
#   'attributes': 'B24032_045M,B24032_045MA,B24032_045EA'},
#  'B08113_049E': {'label': 'Estimate!!Total!!Worked at home',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH',
#   'predicateType': 'int',
#   'group': 'B08113',
#   'limit': 0,
#   'attributes': 'B08113_049M,B08113_049MA,B08113_049EA'},
#  'B01001B_027E': {'label': 'Estimate!!Total!!Female!!45 to 54 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_027M,B01001B_027MA,B01001B_027EA'},
#  'B20005A_023E': {'label': 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With earnings!!$65,000 to $74,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_023M,B20005A_023MA,B20005A_023EA'},
#  'B24022_065E': {'label': 'Estimate!!Total!!Female!!Sales and office occupations!!Office and administrative support occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_065M,B24022_065MA,B24022_065EA'},
#  'B05006PR_019E': {'label': 'Estimate!!Total!!Asia!!Western Asia',
#   'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B05006PR',
#   'limit': 0,
#   'attributes': 'B05006PR_019M,B05006PR_019MA,B05006PR_019EA'},
#  'B25051_002E': {'label': 'Estimate!!Total!!Complete kitchen facilities',
#   'concept': 'KITCHEN FACILITIES FOR ALL HOUSING UNITS',
#   'predicateType': 'int',
#   'group': 'B25051',
#   'limit': 0,
#   'attributes': 'B25051_002M,B25051_002MA,B25051_002EA'},
#  'B99104_004E': {'label': 'Estimate!!Total!!Living with own grandchildren under 18 years!!Grandparent responsible for own grandchildren under 18 years!!Length of time!!Allocated',
#   'concept': 'ALLOCATION OF LENGTH OF TIME GRANDPARENT RESPONSIBLE FOR OWN GRANDCHILDREN UNDER 18 YEARS FOR THE POPULATION 30 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B99104',
#   'limit': 0,
#   'attributes': 'B99104_004EA'},
#  'B24032_044E': {'label': 'Estimate!!Female!!Professional, scientific, and management, and administrative and waste management services!!Professional, scientific, and technical services',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24032',
#   'limit': 0,
#   'attributes': 'B24032_044M,B24032_044MA,B24032_044EA'},
#  'B08113_048E': {'label': 'Estimate!!Total!!Taxicab, motorcycle, bicycle, or other means!!Speak other languages!!Speak English less than "very well"',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH',
#   'predicateType': 'int',
#   'group': 'B08113',
#   'limit': 0,
#   'attributes': 'B08113_048M,B08113_048MA,B08113_048EA'},
#  'B01001B_028E': {'label': 'Estimate!!Total!!Female!!55 to 64 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_028M,B01001B_028MA,B01001B_028EA'},
#  'B19101A_001E': {'label': 'Estimate!!Total',
#   'concept': 'FAMILY INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19101A',
#   'limit': 0,
#   'attributes': 'B19101A_001M,B19101A_001MA,B19101A_001EA'},
#  'B20005A_022E': {'label': 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With earnings!!$55,000 to $64,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_022M,B20005A_022MA,B20005A_022EA'},
#  'B24022_066E': {'label': 'Estimate!!Total!!Female!!Natural resources, construction, and maintenance occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_066M,B24022_066MA,B24022_066EA'},
#  'B24032_043E': {'label': 'Estimate!!Female!!Professional, scientific, and management, and administrative and waste management services',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24032',
#   'limit': 0,
#   'attributes': 'B24032_043M,B24032_043MA,B24032_043EA'},
#  'B11011_009E': {'label': 'Estimate!!Total!!Family households!!Other family!!Male householder, no wife present!!1-unit structures',
#   'concept': 'HOUSEHOLD TYPE BY UNITS IN STRUCTURE',
#   'predicateType': 'int',
#   'group': 'B11011',
#   'limit': 0,
#   'attributes': 'B11011_009M,B11011_009MA,B11011_009EA'},
#  'B01001B_025E': {'label': 'Estimate!!Total!!Female!!30 to 34 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_025M,B01001B_025MA,B01001B_025EA'},
#  'B19101A_002E': {'label': 'Estimate!!Total!!Less than $10,000',
#   'concept': 'FAMILY INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19101A',
#   'limit': 0,
#   'attributes': 'B19101A_002M,B19101A_002MA,B19101A_002EA'},
#  'B20005A_025E': {'label': 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With earnings!!$100,000 or more',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_025M,B20005A_025MA,B20005A_025EA'},
#  'B19037E_030E': {'label': 'Estimate!!Total!!Householder 25 to 44 years!!$60,000 to $74,999',
#   'concept': 'AGE OF HOUSEHOLDER BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19037E',
#   'limit': 0,
#   'attributes': 'B19037E_030M,B19037E_030MA,B19037E_030EA'},
#  'B99104_002E': {'label': 'Estimate!!Total!!Living with own grandchildren under 18 years',
#   'concept': 'ALLOCATION OF LENGTH OF TIME GRANDPARENT RESPONSIBLE FOR OWN GRANDCHILDREN UNDER 18 YEARS FOR THE POPULATION 30 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B99104',
#   'limit': 0,
#   'attributes': 'B99104_002EA'},
#  'B24032_042E': {'label': 'Estimate!!Female!!Finance and insurance, and real estate and rental and leasing!!Real estate and rental and leasing',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24032',
#   'limit': 0,
#   'attributes': 'B24032_042M,B24032_042MA,B24032_042EA'},
#  'B24022_067E': {'label': 'Estimate!!Total!!Female!!Natural resources, construction, and maintenance occupations!!Farming, fishing, and forestry occupations',
#   'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24022',
#   'limit': 0,
#   'attributes': 'B24022_067M,B24022_067MA,B24022_067EA'},
#  'B01001B_026E': {'label': 'Estimate!!Total!!Female!!35 to 44 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_026M,B01001B_026MA,B01001B_026EA'},
#  'B19101A_003E': {'label': 'Estimate!!Total!!$10,000 to $14,999',
#   'concept': 'FAMILY INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19101A',
#   'limit': 0,
#   'attributes': 'B19101A_003M,B19101A_003MA,B19101A_003EA'},
#  'B20005A_024E': {'label': 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With earnings!!$75,000 to $99,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_024M,B20005A_024MA,B20005A_024EA'},
#  'B99104_001E': {'label': 'Estimate!!Total',
#   'concept': 'ALLOCATION OF LENGTH OF TIME GRANDPARENT RESPONSIBLE FOR OWN GRANDCHILDREN UNDER 18 YEARS FOR THE POPULATION 30 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B99104',
#   'limit': 0,
#   'attributes': 'B99104_001EA'},
#  'B07004H_002E': {'label': 'Estimate!!Total!!Same house 1 year ago',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07004H',
#   'limit': 0,
#   'attributes': 'B07004H_002M,B07004H_002MA,B07004H_002EA'},
#  'B07007PR_010E': {'label': 'Estimate!!Total!!Same house 1 year ago!!Foreign born!!Not a U.S. citizen',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_010M,B07007PR_010MA,B07007PR_010EA'},
#  'B24032_041E': {'label': 'Estimate!!Female!!Finance and insurance, and real estate and rental and leasing!!Finance and insurance',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24032',
#   'limit': 0,
#   'attributes': 'B24032_041M,B24032_041MA,B24032_041EA'},
#  'B05006PR_016E': {'label': 'Estimate!!Total!!Asia!!Eastern Asia!!Other Eastern Asia',
#   'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B05006PR',
#   'limit': 0,
#   'attributes': 'B05006PR_016M,B05006PR_016MA,B05006PR_016EA'},
#  'B06010_047E': {'label': 'Estimate!!Total!!Foreign born!!With income',
#   'concept': 'PLACE OF BIRTH BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06010',
#   'limit': 0,
#   'attributes': 'B06010_047M,B06010_047MA,B06010_047EA'},
#  'B01001B_022E': {'label': 'Estimate!!Total!!Female!!18 and 19 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_022M,B01001B_022MA,B01001B_022EA'},
#  'B20005_028E': {'label': 'Estimate!!Total!!Male!!Other!!With earnings',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_028M,B20005_028MA,B20005_028EA'},
#  'B01001B_023E': {'label': 'Estimate!!Total!!Female!!20 to 24 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_023M,B01001B_023MA,B01001B_023EA'},
#  'B17018_009E': {'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Other families!!Male householder, no wife present',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'predicateType': 'int',
#   'group': 'B17018',
#   'limit': 0,
#   'attributes': 'B17018_009M,B17018_009MA,B17018_009EA'},
#  'B07004H_001E': {'label': 'Estimate!!Total',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07004H',
#   'limit': 0,
#   'attributes': 'B07004H_001M,B07004H_001MA,B07004H_001EA'},
#  'B24032_040E': {'label': 'Estimate!!Female!!Finance and insurance, and real estate and rental and leasing',
#   'concept': 'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24032',
#   'limit': 0,
#   'attributes': 'B24032_040M,B24032_040MA,B24032_040EA'},
#  'B05006PR_015E': {'label': 'Estimate!!Total!!Asia!!Eastern Asia!!Korea',
#   'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B05006PR',
#   'limit': 0,
#   'attributes': 'B05006PR_015M,B05006PR_015MA,B05006PR_015EA'},
#  'B06010_046E': {'label': 'Estimate!!Total!!Foreign born!!No income',
#   'concept': 'PLACE OF BIRTH BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06010',
#   'limit': 0,
#   'attributes': 'B06010_046M,B06010_046MA,B06010_046EA'},
#  'B20005_029E': {'label': 'Estimate!!Total!!Male!!Other!!With earnings!!$1 to $2,499 or loss',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_029M,B20005_029MA,B20005_029EA'},
#  'B01001B_024E': {'label': 'Estimate!!Total!!Female!!25 to 29 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_024M,B01001B_024MA,B01001B_024EA'},
#  'B05006PR_014E': {'label': 'Estimate!!Total!!Asia!!Eastern Asia!!China!!Taiwan',
#   'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B05006PR',
#   'limit': 0,
#   'attributes': 'B05006PR_014M,B05006PR_014MA,B05006PR_014EA'},
#  'B17018_008E': {'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Other families',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'predicateType': 'int',
#   'group': 'B17018',
#   'limit': 0,
#   'attributes': 'B17018_008M,B17018_008MA,B17018_008EA'},
#  'B25051_003E': {'label': 'Estimate!!Total!!Lacking complete kitchen facilities',
#   'concept': 'KITCHEN FACILITIES FOR ALL HOUSING UNITS',
#   'predicateType': 'int',
#   'group': 'B25051',
#   'limit': 0,
#   'attributes': 'B25051_003M,B25051_003MA,B25051_003EA'},
#  'B05006PR_018E': {'label': 'Estimate!!Total!!Asia!!South Eastern Asia',
#   'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B05006PR',
#   'limit': 0,
#   'attributes': 'B05006PR_018M,B05006PR_018MA,B05006PR_018EA'},
#  'B06010_049E': {'label': 'Estimate!!Total!!Foreign born!!With income!!$10,000 to $14,999',
#   'concept': 'PLACE OF BIRTH BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06010',
#   'limit': 0,
#   'attributes': 'B06010_049M,B06010_049MA,B06010_049EA'},
#  'B01001B_020E': {'label': 'Estimate!!Total!!Female!!10 to 14 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_020M,B01001B_020MA,B01001B_020EA'},
#  'B20005_026E': {'label': 'Estimate!!Total!!Male!!Other',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_026M,B20005_026MA,B20005_026EA'},
#  'B06004E_001E': {'label': 'Estimate!!Total',
#   'concept': 'PLACE OF BIRTH (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06004E',
#   'limit': 0,
#   'attributes': 'B06004E_001M,B06004E_001MA,B06004E_001EA'},
#  'B17018_007E': {'label': "Estimate!!Total!!Income in the past 12 months below poverty level!!Married-couple family!!Bachelor's degree or higher",
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'predicateType': 'int',
#   'group': 'B17018',
#   'limit': 0,
#   'attributes': 'B17018_007M,B17018_007MA,B17018_007EA'},
#  'B17018_005E': {'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Married-couple family!!High school graduate (includes equivalency)',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'predicateType': 'int',
#   'group': 'B17018',
#   'limit': 0,
#   'attributes': 'B17018_005M,B17018_005MA,B17018_005EA'},
#  'B05006PR_017E': {'label': 'Estimate!!Total!!Asia!!South Central Asia',
#   'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B05006PR',
#   'limit': 0,
#   'attributes': 'B05006PR_017M,B05006PR_017MA,B05006PR_017EA'},
#  'B06010_048E': {'label': 'Estimate!!Total!!Foreign born!!With income!!$1 to $9,999 or loss',
#   'concept': 'PLACE OF BIRTH BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06010',
#   'limit': 0,
#   'attributes': 'B06010_048M,B06010_048MA,B06010_048EA'},
#  'B01001B_021E': {'label': 'Estimate!!Total!!Female!!15 to 17 years',
#   'concept': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'predicateType': 'int',
#   'group': 'B01001B',
#   'limit': 0,
#   'attributes': 'B01001B_021M,B01001B_021MA,B01001B_021EA'},
#  'B20005_027E': {'label': 'Estimate!!Total!!Male!!Other!!No earnings',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_027M,B20005_027MA,B20005_027EA'},
#  'B06004E_002E': {'label': 'Estimate!!Total!!Born in state of residence',
#   'concept': 'PLACE OF BIRTH (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06004E',
#   'limit': 0,
#   'attributes': 'B06004E_002M,B06004E_002MA,B06004E_002EA'},
#  'B24123_120E': {'label': 'Estimate!!Total!!Social workers',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24123',
#   'limit': 0,
#   'attributes': 'B24123_120M,B24123_120MA,B24123_120EA'},
#  'B17018_006E': {'label': "Estimate!!Total!!Income in the past 12 months below poverty level!!Married-couple family!!Some college, associate's degree",
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'predicateType': 'int',
#   'group': 'B17018',
#   'limit': 0,
#   'attributes': 'B17018_006M,B17018_006MA,B17018_006EA'},
#  'B06010_043E': {'label': 'Estimate!!Total!!Native; born outside the United States!!With income!!$65,000 to $74,999',
#   'concept': 'PLACE OF BIRTH BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06010',
#   'limit': 0,
#   'attributes': 'B06010_043M,B06010_043MA,B06010_043EA'},
#  'B24126_499E': {'label': 'Estimate!!Total!!Motor vehicle operators, all other',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24126',
#   'limit': 0,
#   'attributes': 'B24126_499M,B24126_499MA,B24126_499EA'},
#  'B17018_004E': {'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Married-couple family!!Less than high school graduate',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'predicateType': 'int',
#   'group': 'B17018',
#   'limit': 0,
#   'attributes': 'B17018_004M,B17018_004MA,B17018_004EA'},
#  'B07004H_006E': {'label': 'Estimate!!Total!!Moved from abroad',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07004H',
#   'limit': 0,
#   'attributes': 'B07004H_006M,B07004H_006MA,B07004H_006EA'},
#  'B07007PR_014E': {'label': 'Estimate!!Total!!Moved within same municipio!!Foreign born!!Naturalized U.S. citizen',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_014M,B07007PR_014MA,B07007PR_014EA'},
#  'B08119_021E': {'label': 'Estimate!!Total!!Car, truck, or van - carpooled!!$10,000 to $14,999',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS)",
#   'predicateType': 'int',
#   'group': 'B08119',
#   'limit': 0,
#   'attributes': 'B08119_021M,B08119_021MA,B08119_021EA'},
#  'B11011_002E': {'label': 'Estimate!!Total!!Family households',
#   'concept': 'HOUSEHOLD TYPE BY UNITS IN STRUCTURE',
#   'predicateType': 'int',
#   'group': 'B11011',
#   'limit': 0,
#   'attributes': 'B11011_002M,B11011_002MA,B11011_002EA'},
#  'B06004E_003E': {'label': 'Estimate!!Total!!Born in other state in the United States',
#   'concept': 'PLACE OF BIRTH (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06004E',
#   'limit': 0,
#   'attributes': 'B06004E_003M,B06004E_003MA,B06004E_003EA'},
#  'B05006PR_011E': {'label': 'Estimate!!Total!!Asia!!Eastern Asia',
#   'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B05006PR',
#   'limit': 0,
#   'attributes': 'B05006PR_011M,B05006PR_011MA,B05006PR_011EA'},
#  'B24126_498E': {'label': 'Estimate!!Total!!Taxi drivers and chauffeurs',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24126',
#   'limit': 0,
#   'attributes': 'B24126_498M,B24126_498MA,B24126_498EA'},
#  'B17018_003E': {'label': 'Estimate!!Total!!Income in the past 12 months below poverty level!!Married-couple family',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'predicateType': 'int',
#   'group': 'B17018',
#   'limit': 0,
#   'attributes': 'B17018_003M,B17018_003MA,B17018_003EA'},
#  'B06010_042E': {'label': 'Estimate!!Total!!Native; born outside the United States!!With income!!$50,000 to $64,999',
#   'concept': 'PLACE OF BIRTH BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06010',
#   'limit': 0,
#   'attributes': 'B06010_042M,B06010_042MA,B06010_042EA'},
#  'B07004H_005E': {'label': 'Estimate!!Total!!Moved from different state',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07004H',
#   'limit': 0,
#   'attributes': 'B07004H_005M,B07004H_005MA,B07004H_005EA'},
#  'B07007PR_013E': {'label': 'Estimate!!Total!!Moved within same municipio!!Foreign born',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_013M,B07007PR_013MA,B07007PR_013EA'},
#  'B19001B_017E': {'label': 'Estimate!!Total!!$200,000 or more',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_017M,B19001B_017MA,B19001B_017EA'},
#  'B08119_020E': {'label': 'Estimate!!Total!!Car, truck, or van - carpooled!!$1 to $9,999 or loss',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS)",
#   'predicateType': 'int',
#   'group': 'B08119',
#   'limit': 0,
#   'attributes': 'B08119_020M,B08119_020MA,B08119_020EA'},
#  'B11011_003E': {'label': 'Estimate!!Total!!Family households!!Married-couple family',
#   'concept': 'HOUSEHOLD TYPE BY UNITS IN STRUCTURE',
#   'predicateType': 'int',
#   'group': 'B11011',
#   'limit': 0,
#   'attributes': 'B11011_003M,B11011_003MA,B11011_003EA'},
#  'B06004E_004E': {'label': 'Estimate!!Total!!Native; born outside the United States',
#   'concept': 'PLACE OF BIRTH (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06004E',
#   'limit': 0,
#   'attributes': 'B06004E_004M,B06004E_004MA,B06004E_004EA'},
#  'B05006PR_010E': {'label': 'Estimate!!Total!!Asia',
#   'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B05006PR',
#   'limit': 0,
#   'attributes': 'B05006PR_010M,B05006PR_010MA,B05006PR_010EA'},
#  'B24126_497E': {'label': 'Estimate!!Total!!Driver/sales workers and truck drivers',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24126',
#   'limit': 0,
#   'attributes': 'B24126_497M,B24126_497MA,B24126_497EA'},
#  'B17018_002E': {'label': 'Estimate!!Total!!Income in the past 12 months below poverty level',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'predicateType': 'int',
#   'group': 'B17018',
#   'limit': 0,
#   'attributes': 'B17018_002M,B17018_002MA,B17018_002EA'},
#  'B06010_045E': {'label': 'Estimate!!Total!!Foreign born',
#   'concept': 'PLACE OF BIRTH BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06010',
#   'limit': 0,
#   'attributes': 'B06010_045M,B06010_045MA,B06010_045EA'},
#  'B07004H_004E': {'label': 'Estimate!!Total!!Moved from different county within same state',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07004H',
#   'limit': 0,
#   'attributes': 'B07004H_004M,B07004H_004MA,B07004H_004EA'},
#  'B07007PR_012E': {'label': 'Estimate!!Total!!Moved within same municipio!!Native',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_012M,B07007PR_012MA,B07007PR_012EA'},
#  'B19001B_016E': {'label': 'Estimate!!Total!!$150,000 to $199,999',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_016M,B19001B_016MA,B19001B_016EA'},
#  'B06004E_005E': {'label': 'Estimate!!Total!!Foreign born',
#   'concept': 'PLACE OF BIRTH (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06004E',
#   'limit': 0,
#   'attributes': 'B06004E_005M,B06004E_005MA,B06004E_005EA'},
#  'B05006PR_013E': {'label': 'Estimate!!Total!!Asia!!Eastern Asia!!China!!China, excluding Taiwan',
#   'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B05006PR',
#   'limit': 0,
#   'attributes': 'B05006PR_013M,B05006PR_013MA,B05006PR_013EA'},
#  'B07004H_003E': {'label': 'Estimate!!Total!!Moved within same county',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B07004H',
#   'limit': 0,
#   'attributes': 'B07004H_003M,B07004H_003MA,B07004H_003EA'},
#  'B07007PR_011E': {'label': 'Estimate!!Total!!Moved within same municipio',
#   'concept': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B07007PR',
#   'limit': 0,
#   'attributes': 'B07007PR_011M,B07007PR_011MA,B07007PR_011EA'},
#  'B06010_044E': {'label': 'Estimate!!Total!!Native; born outside the United States!!With income!!$75,000 or more',
#   'concept': 'PLACE OF BIRTH BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) IN THE UNITED STATES',
#   'predicateType': 'int',
#   'group': 'B06010',
#   'limit': 0,
#   'attributes': 'B06010_044M,B06010_044MA,B06010_044EA'},
#  'B17018_001E': {'label': 'Estimate!!Total',
#   'concept': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'predicateType': 'int',
#   'group': 'B17018',
#   'limit': 0,
#   'attributes': 'B17018_001M,B17018_001MA,B17018_001EA'},
#  'B19001B_015E': {'label': 'Estimate!!Total!!$125,000 to $149,999',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'predicateType': 'int',
#   'group': 'B19001B',
#   'limit': 0,
#   'attributes': 'B19001B_015M,B19001B_015MA,B19001B_015EA'},
#  'B11011_001E': {'label': 'Estimate!!Total',
#   'concept': 'HOUSEHOLD TYPE BY UNITS IN STRUCTURE',
#   'predicateType': 'int',
#   'group': 'B11011',
#   'limit': 0,
#   'attributes': 'B11011_001M,B11011_001MA,B11011_001EA'},
#  'B05006PR_012E': {'label': 'Estimate!!Total!!Asia!!Eastern Asia!!China',
#   'concept': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION IN PUERTO RICO',
#   'predicateType': 'int',
#   'group': 'B05006PR',
#   'limit': 0,
#   'attributes': 'B05006PR_012M,B05006PR_012MA,B05006PR_012EA'},
#  'B08201_007E': {'label': 'Estimate!!Total!!1-person household',
#   'concept': 'HOUSEHOLD SIZE BY VEHICLES AVAILABLE',
#   'predicateType': 'int',
#   'group': 'B08201',
#   'limit': 0,
#   'attributes': 'B08201_007M,B08201_007MA,B08201_007EA'},
#  'B25122_115E': {'label': 'Estimate!!Total!!Household income in the past 12 months (in 2016 inflation-adjusted dollars)!!$100,000 or more!!With cash rent!!$900 to $999',
#   'concept': 'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'predicateType': 'int',
#   'group': 'B25122',
#   'limit': 0,
#   'attributes': 'B25122_115M,B25122_115MA,B25122_115EA'},
#  'B16005F_010E': {'label': 'Estimate!!Total!!Foreign born!!Speak another language!!Speak English "very well"',
#   'concept': 'NATIVITY BY LANGUAGE SPOKEN AT HOME BY ABILITY TO SPEAK ENGLISH FOR THE POPULATION 5 YEARS AND OVER (SOME OTHER RACE ALONE)',
#   'predicateType': 'int',
#   'group': 'B16005F',
#   'limit': 0,
#   'attributes': 'B16005F_010M,B16005F_010MA,B16005F_010EA'},
#  'B08119_025E': {'label': 'Estimate!!Total!!Car, truck, or van - carpooled!!$50,000 to $64,999',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS)",
#   'predicateType': 'int',
#   'group': 'B08119',
#   'limit': 0,
#   'attributes': 'B08119_025M,B08119_025MA,B08119_025EA'},
#  'B19037E_028E': {'label': 'Estimate!!Total!!Householder 25 to 44 years!!$45,000 to $49,999',
# ...
#  'B24123_162E': {'label': 'Estimate!!Total!!Dentists',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24123',
#   'limit': 0,
#   'attributes': 'B24123_162M,B24123_162MA,B24123_162EA'},
#  'B14004_010E': {'label': 'Estimate!!Total!!Male!!Enrolled in private college or graduate school!!18 to 24 years',
#   'concept': 'SEX BY COLLEGE OR GRADUATE SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 15 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B14004',
#   'limit': 0,
#   'attributes': 'B14004_010M,B14004_010MA,B14004_010EA'},
#  'B20005A_062E': {'label': 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With earnings!!$22,500 to $24,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_062M,B20005A_062MA,B20005A_062EA'},
#  'B24126_013E': {'label': 'Estimate!!Total!!Training and development managers',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24126',
#   'limit': 0,
#   'attributes': 'B24126_013M,B24126_013MA,B24126_013EA'},
#  'B24126_017E': {'label': 'Estimate!!Total!!Farmers, ranchers, and other agricultural managers',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24126',
#   'limit': 0,
#   'attributes': 'B24126_017M,B24126_017MA,B24126_017EA'},
#  'B25068_029E': {'label': 'Estimate!!Total!!3 or more bedrooms',
#   'concept': 'BEDROOMS BY GROSS RENT',
#   'predicateType': 'int',
#   'group': 'B25068',
#   'limit': 0,
#   'attributes': 'B25068_029M,B25068_029MA,B25068_029EA'},
#  'B25115_021E': {'label': 'Estimate!!Total!!Renter occupied!!Family households!!Other family!!Male householder, no wife present',
#   'concept': 'TENURE BY HOUSEHOLD TYPE AND PRESENCE AND AGE OF OWN CHILDREN',
#   'predicateType': 'int',
#   'group': 'B25115',
#   'limit': 0,
#   'attributes': 'B25115_021M,B25115_021MA,B25115_021EA'},
#  'B08519_004E': {'label': 'Estimate!!Total!!$15,000 to $24,999',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR WORKPLACE GEOGRAPHY",
#   'predicateType': 'int',
#   'group': 'B08519',
#   'limit': 0,
#   'attributes': 'B08519_004M,B08519_004MA,B08519_004EA'},
#  'B20005H_062E': {'label': 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With earnings!!$22,500 to $24,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'predicateType': 'int',
#   'group': 'B20005H',
#   'limit': 0,
#   'attributes': 'B20005H_062M,B20005H_062MA,B20005H_062EA'},
#  'B23008_014E': {'label': 'Estimate!!Total!!Under 6 years!!Living with one parent!!Living with mother!!Not in labor force',
#   'concept': 'AGE OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS BY EMPLOYMENT STATUS OF PARENTS',
#   'predicateType': 'int',
#   'group': 'B23008',
#   'limit': 0,
#   'attributes': 'B23008_014M,B23008_014MA,B23008_014EA'},
#  'B25007_021E': {'label': 'Estimate!!Total!!Renter occupied!!Householder 85 years and over',
#   'concept': 'TENURE BY AGE OF HOUSEHOLDER',
#   'predicateType': 'int',
#   'group': 'B25007',
#   'limit': 0,
#   'attributes': 'B25007_021M,B25007_021MA,B25007_021EA'},
#  'B08524_045E': {'label': 'Estimate!!Total!!Worked at home!!Service occupations',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY OCCUPATION FOR WORKPLACE GEOGRAPHY',
#   'predicateType': 'int',
#   'group': 'B08524',
#   'limit': 0,
#   'attributes': 'B08524_045M,B08524_045MA,B08524_045EA'},
#  'B13015_003E': {'label': 'Estimate!!Total!!Women who had a birth in the past 12 months!!Now married (including separated and spouse absent)',
#   'concept': 'WOMEN 15 TO 50 YEARS WHO HAD A BIRTH IN THE PAST 12 MONTHS BY MARITAL STATUS AND RECEIPT OF PUBLIC ASSISTANCE INCOME IN THE PAST 12 MONTHS',
#   'predicateType': 'int',
#   'group': 'B13015',
#   'limit': 0,
#   'attributes': 'B13015_003M,B13015_003MA,B13015_003EA'},
#  'B02014_043E': {'label': 'Estimate!!Total!!American Indian tribes, specified!!Yuman',
#   'concept': 'AMERICAN INDIAN AND ALASKA NATIVE ALONE FOR SELECTED TRIBAL GROUPINGS',
#   'predicateType': 'int',
#   'group': 'B02014',
#   'limit': 0,
#   'attributes': 'B02014_043M,B02014_043MA,B02014_043EA'},
#  'B24123_163E': {'label': 'Estimate!!Total!!Dietitians and nutritionists',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24123',
#   'limit': 0,
#   'attributes': 'B24123_163M,B24123_163MA,B24123_163EA'},
#  'B24122_318E': {'label': 'Estimate!!Total!!Weighers, measurers, checkers, and samplers, recordkeeping',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24122',
#   'limit': 0,
#   'attributes': 'B24122_318M,B24122_318MA,B24122_318EA'},
#  'B20005A_065E': {'label': 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With earnings!!$35,000 to $39,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_065M,B20005A_065MA,B20005A_065EA'},
#  'B25115_020E': {'label': 'Estimate!!Total!!Renter occupied!!Family households!!Other family',
#   'concept': 'TENURE BY HOUSEHOLD TYPE AND PRESENCE AND AGE OF OWN CHILDREN',
#   'predicateType': 'int',
#   'group': 'B25115',
#   'limit': 0,
#   'attributes': 'B25115_020M,B25115_020MA,B25115_020EA'},
#  'B24126_016E': {'label': 'Estimate!!Total!!Transportation, storage, and distribution managers',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24126',
#   'limit': 0,
#   'attributes': 'B24126_016M,B24126_016MA,B24126_016EA'},
#  'B25068_028E': {'label': 'Estimate!!Total!!2 bedrooms!!No cash rent',
#   'concept': 'BEDROOMS BY GROSS RENT',
#   'predicateType': 'int',
#   'group': 'B25068',
#   'limit': 0,
#   'attributes': 'B25068_028M,B25068_028MA,B25068_028EA'},
#  'B20005H_061E': {'label': 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With earnings!!$20,000 to $22,499',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'predicateType': 'int',
#   'group': 'B20005H',
#   'limit': 0,
#   'attributes': 'B20005H_061M,B20005H_061MA,B20005H_061EA'},
#  'B08519_003E': {'label': 'Estimate!!Total!!$10,000 to $14,999',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR WORKPLACE GEOGRAPHY",
#   'predicateType': 'int',
#   'group': 'B08519',
#   'limit': 0,
#   'attributes': 'B08519_003M,B08519_003MA,B08519_003EA'},
#  'B23008_013E': {'label': 'Estimate!!Total!!Under 6 years!!Living with one parent!!Living with mother!!In labor force',
#   'concept': 'AGE OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS BY EMPLOYMENT STATUS OF PARENTS',
#   'predicateType': 'int',
#   'group': 'B23008',
#   'limit': 0,
#   'attributes': 'B23008_013M,B23008_013MA,B23008_013EA'},
#  'B13015_002E': {'label': 'Estimate!!Total!!Women who had a birth in the past 12 months',
#   'concept': 'WOMEN 15 TO 50 YEARS WHO HAD A BIRTH IN THE PAST 12 MONTHS BY MARITAL STATUS AND RECEIPT OF PUBLIC ASSISTANCE INCOME IN THE PAST 12 MONTHS',
#   'predicateType': 'int',
#   'group': 'B13015',
#   'limit': 0,
#   'attributes': 'B13015_002M,B13015_002MA,B13015_002EA'},
#  'B08524_046E': {'label': 'Estimate!!Total!!Worked at home!!Sales and office occupations',
#   'concept': 'MEANS OF TRANSPORTATION TO WORK BY OCCUPATION FOR WORKPLACE GEOGRAPHY',
#   'predicateType': 'int',
#   'group': 'B08524',
#   'limit': 0,
#   'attributes': 'B08524_046M,B08524_046MA,B08524_046EA'},
#  'B24122_317E': {'label': 'Estimate!!Total!!Stock clerks and order fillers',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED MALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24122',
#   'limit': 0,
#   'attributes': 'B24122_317M,B24122_317MA,B24122_317EA'},
#  'B02014_042E': {'label': 'Estimate!!Total!!American Indian tribes, specified!!Yaqui',
#   'concept': 'AMERICAN INDIAN AND ALASKA NATIVE ALONE FOR SELECTED TRIBAL GROUPINGS',
#   'predicateType': 'int',
#   'group': 'B02014',
#   'limit': 0,
#   'attributes': 'B02014_042M,B02014_042MA,B02014_042EA'},
#  'B24123_164E': {'label': 'Estimate!!Total!!Optometrists',
#   'concept': 'DETAILED OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24123',
#   'limit': 0,
#   'attributes': 'B24123_164M,B24123_164MA,B24123_164EA'},
#  'B20005A_064E': {'label': 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With earnings!!$30,000 to $34,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'predicateType': 'int',
#   'group': 'B20005A',
#   'limit': 0,
#   'attributes': 'B20005A_064M,B20005A_064MA,B20005A_064EA'},
#  'B12006_035E': {'label': 'Estimate!!Total!!Widowed',
#   'concept': 'MARITAL STATUS BY SEX BY LABOR FORCE PARTICIPATION',
#   'predicateType': 'int',
#   'group': 'B12006',
#   'limit': 0,
#   'attributes': 'B12006_035M,B12006_035MA,B12006_035EA'},
#  'B08519_002E': {'label': 'Estimate!!Total!!$1 to $9,999 or loss',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR WORKPLACE GEOGRAPHY",
#   'predicateType': 'int',
#   'group': 'B08519',
#   'limit': 0,
#   'attributes': 'B08519_002M,B08519_002MA,B08519_002EA'},
#  'B02014_037E': {'label': 'Estimate!!Total!!American Indian tribes, specified!!South American Indian',
#   'concept': 'AMERICAN INDIAN AND ALASKA NATIVE ALONE FOR SELECTED TRIBAL GROUPINGS',
#   'predicateType': 'int',
#   'group': 'B02014',
#   'limit': 0,
#   'attributes': 'B02014_037M,B02014_037MA,B02014_037EA'},
#  'B20005_068E': {'label': 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With earnings!!$50,000 to $54,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_068M,B20005_068MA,B20005_068EA'},
#  'B14004_001E': {'label': 'Estimate!!Total',
#   'concept': 'SEX BY COLLEGE OR GRADUATE SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 15 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B14004',
#   'limit': 0,
#   'attributes': 'B14004_001M,B14004_001MA,B14004_001EA'},
#  'B24126_010E': {'label': 'Estimate!!Total!!Financial managers',
#   'concept': 'DETAILED OCCUPATION FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED FEMALE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B24126',
#   'limit': 0,
#   'attributes': 'B24126_010M,B24126_010MA,B24126_010EA'},
#  'B08519_001E': {'label': 'Estimate!!Total',
#   'concept': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR WORKPLACE GEOGRAPHY",
#   'predicateType': 'int',
#   'group': 'B08519',
#   'limit': 0,
#   'attributes': 'B08519_001M,B08519_001MA,B08519_001EA'},
#  'B05011_005E': {'label': 'Estimate!!Total!!Naturalized citizens!!Naturalized 2005 to 2009',
#   'concept': 'PERIOD OF NATURALIZATION',
#   'predicateType': 'int',
#   'group': 'B05011',
#   'limit': 0,
#   'attributes': 'B05011_005M,B05011_005MA,B05011_005EA'},
#  'B12006_034E': {'label': 'Estimate!!Total!!Separated!!Female!!Not in labor force',
#   'concept': 'MARITAL STATUS BY SEX BY LABOR FORCE PARTICIPATION',
#   'predicateType': 'int',
#   'group': 'B12006',
#   'limit': 0,
#   'attributes': 'B12006_034M,B12006_034MA,B12006_034EA'},
#  'B25125_001E': {'label': 'Estimate!!Total',
#   'concept': 'TENURE BY AGE OF HOUSEHOLDER BY UNITS IN STRUCTURE',
#   'predicateType': 'int',
#   'group': 'B25125',
#   'limit': 0,
#   'attributes': 'B25125_001M,B25125_001MA,B25125_001EA'},
#  'B02014_036E': {'label': 'Estimate!!Total!!American Indian tribes, specified!!Sioux',
#   'concept': 'AMERICAN INDIAN AND ALASKA NATIVE ALONE FOR SELECTED TRIBAL GROUPINGS',
#   'predicateType': 'int',
#   'group': 'B02014',
#   'limit': 0,
#   'attributes': 'B02014_036M,B02014_036MA,B02014_036EA'},
#  'B20005_069E': {'label': 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With earnings!!$55,000 to $64,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_069M,B20005_069MA,B20005_069EA'},
#  'B05011_006E': {'label': 'Estimate!!Total!!Naturalized citizens!!Naturalized 2000 to 2004',
#   'concept': 'PERIOD OF NATURALIZATION',
#   'predicateType': 'int',
#   'group': 'B05011',
#   'limit': 0,
#   'attributes': 'B05011_006M,B05011_006MA,B05011_006EA'},
#  'B12006_033E': {'label': 'Estimate!!Total!!Separated!!Female!!In labor force!!Unemployed',
#   'concept': 'MARITAL STATUS BY SEX BY LABOR FORCE PARTICIPATION',
#   'predicateType': 'int',
#   'group': 'B12006',
#   'limit': 0,
#   'attributes': 'B12006_033M,B12006_033MA,B12006_033EA'},
#  'B14004_002E': {'label': 'Estimate!!Total!!Male',
#   'concept': 'SEX BY COLLEGE OR GRADUATE SCHOOL ENROLLMENT BY TYPE OF SCHOOL BY AGE FOR THE POPULATION 15 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B14004',
#   'limit': 0,
#   'attributes': 'B14004_002M,B14004_002MA,B14004_002EA'},
#  'B25061_020E': {'label': 'Estimate!!Total!!$1,250 to $1,499',
#   'concept': 'RENT ASKED',
#   'predicateType': 'int',
#   'group': 'B25061',
#   'limit': 0,
#   'attributes': 'B25061_020M,B25061_020MA,B25061_020EA'},
#  'B12006_037E': {'label': 'Estimate!!Total!!Widowed!!Male!!In labor force',
#   'concept': 'MARITAL STATUS BY SEX BY LABOR FORCE PARTICIPATION',
#   'predicateType': 'int',
#   'group': 'B12006',
#   'limit': 0,
#   'attributes': 'B12006_037M,B12006_037MA,B12006_037EA'},
#  'B20005_065E': {'label': 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With earnings!!$35,000 to $39,999',
#   'concept': 'SEX BY WORK EXPERIENCE IN THE PAST 12 MONTHS BY EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 16 YEARS AND OVER',
#   'predicateType': 'int',
#   'group': 'B20005',
#   'limit': 0,
#   'attributes': 'B20005_065M,B20005_065MA,B20005_065EA'},
#  'B02014_035E': {'label': 'Estimate!!Total!!American Indian tribes, specified!!Shoshone',
#   'concept': 'AMERICAN INDIAN AND ALASKA NATIVE ALONE FOR SELECTED TRIBAL GROUPINGS',
#   'predicateType': 'int',
#   'group': 'B02014',
#   'limit': 0,
#   'attributes': 'B02014_035M,B02014_035MA,B02014_035EA'},
#  ...}
